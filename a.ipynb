# %%
import polars as pl
import irr

# %%
payments = pl.read_csv("payments 1116 final 1 1.csv",infer_schema=False)
disbursements = pl.read_csv("disbursements 1116 3.csv",infer_schema=False)

# %%
data = {"payments": payments, "disbursements": disbursements}

# %%
my_data = irr.process_dataframe(data)
my_data
# Out:
# {'disbursements': shape: (4, 10)
#  ┌────────┬────────────┬────────────┬────────────┬───┬─────────┬────────────┬──────────┬────────────┐
#  │ Sl.No. ┆ Date       ┆ Loan       ┆ CG         ┆ … ┆ Loan ID ┆ Amendment  ┆ Location ┆ Capitaliza │
#  │ ---    ┆ ---        ┆ amount     ┆ Allocation ┆   ┆ ---     ┆ ---        ┆ ---      ┆ tion Date  │
#  │ str    ┆ str        ┆ ---        ┆ ---        ┆   ┆ str     ┆ str        ┆ str      ┆ ---        │
#  │        ┆            ┆ str        ┆ str        ┆   ┆         ┆            ┆          ┆ str        │
#  ╞════════╪════════════╪════════════╪════════════╪═══╪═════════╪════════════╪══════════╪════════════╡
#  │ 1      ┆ 01-04-2024 ┆ 307520000  ┆ 4612321.38 ┆ … ┆ Loan1   ┆ 01-04-2024 ┆ .        ┆ 01-04-2024 │
#  │        ┆            ┆            ┆ 8          ┆   ┆         ┆            ┆          ┆            │
#  │ 1      ┆ 30-09-2024 ┆ 3075.2     ┆ 46.1232138 ┆ … ┆ Loan1   ┆ 01-04-2024 ┆ .        ┆ 01-04-2024 │
# ...
